# %% [markdown]
# # Pump failure example with Pareto prior
#
# This notebook demonstrates the use of `MGFDerivative` with a Pareto prior for the Poisson likelihood, using the classic pump failure data from Gaver and O'Muircheartaigh (1987).
#
# We will:
# - Compute the model evidence (marginal likelihood)
# - Compute the posterior density
# - Compute the posterior predictive mass for a new observation
# - Compute the posterior MGF and moments
# - Demonstrate sequential updating by splitting the data into two chunks
#
# All examples use the **single‑rate model** with a diffuse Pareto prior $ \Lambda \sim \text{Pareto}(\alpha=10^{-5}, \xi=10^{-5}) $. This matches the setup in the paper.
#
# ## Setup

# %%
import pandas as pd
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
from MGFderivative_class import MGFDerivative
from like_stats.Poisson import readyPoisson
from scipy.special import expn
import mpmath as mp
import numpy as np
import math

plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ## Pump failure data

# %%
data = pd.DataFrame({
    't': [94.32, 15.72, 62.88, 125.76, 5.24, 31.44, 1.048, 1.048, 2.096, 10.48],
    'y': [5, 1, 5, 14, 3, 19, 1, 1, 4, 22]
})
print("Data:")
display(data)
# Out:
# Data:
#          t   y
# 0   94.320   5
# 1   15.720   1
# 2   62.880   5
# 3  125.760  14
# 4    5.240   3
# 5   31.440  19
# 6    1.048   1
# 7    1.048   1
# 8    2.096   4
# 9   10.480  22

# %% [markdown]
# ## Prior specification
#
# We use a Pareto prior with shape `α = 1e-5` and scale `ξ = 1e-5` (very diffuse). Note that the Poisson likelihood gives an integer derivative order (`a = sum(y_i)`), so we will use `method='symbolic'` for exact computation.

# %%
alpha_prior = 1e-5
xi_prior = 1e-5
params_pareto = {'alpha': alpha_prior, 'xi': xi_prior}

# %% [markdown]
# ## 1. Model evidence
#
# The evidence is computed via the derivative of the prior MGF at `t = -b`. We compute it symbolically and compare with the analytic formula from the paper.

# %%
# Compute evidence using the package
alpha_prior = 1e-5
xi_prior = 1e-5
params_pareto = {'alpha': alpha_prior, 'xi': xi_prior}

deriv = MGFDerivative(
    prior='pareto',
    data=data['y'],
    likelihood='poisson',
    method='symbolic',
    params=params_pareto,
    scale=data['t']
)

log_ev_pkg, sign_pkg = deriv.evidence()
print(f"Package log evidence: {log_ev_pkg:.6f}, sign = {sign_pkg}")
# Out:
# Package log evidence: -91.738538, sign = 1

# %% [markdown]
# **1.2 Analytical verification using the paper's formula**
#
# The evidence for the single‑rate Pareto‑Poisson model is given by Equation (14) in the paper:
#
# $$
# p(\mathbf{y}) = \left(\prod_{i=1}^n \frac{t_i^{y_i}}{y_i!}\right) \, \alpha \, \xi^{\sum y_i} \, E_{\alpha+1-\sum y_i}\left(\xi \sum t_i\right),
# $$
#
# where $E_n(z)$ is the exponential integral function. We can verify the package result by directly substituting the hyperparameters into the symbolic derivative expression obtained from the package.

# %%
# Set high precision for accurate evaluation
mp.mp.dps = 50  # note: use mp.mp.dps, not mp.dps

# Compute statistics
a = sum(data['y'])
b = sum(data['t'])
c_val = np.prod(data['t']**data['y'] / [math.factorial(int(yi)) for yi in data['y']])

# Hyperparameters
alpha_prior = 1e-5
xi_prior = 1e-5

# Order and argument of the exponential integral
n_expint = alpha_prior + 1 - a
z_expint = xi_prior * b

# Evaluate E_n(z) using mpmath (supports negative n)
E_val = mp.expint(n_expint, z_expint)

# Compute log evidence
log_ev_analytic = np.log(c_val) + np.log(alpha_prior) + a * np.log(xi_prior) + np.log(float(E_val))
print(f"Analytical log evidence (mpmath): {log_ev_analytic:.6f}")

# Compare with package result (from previous chunk)
print(f"Package log evidence: {log_ev_pkg:.6f}")
print(f"Difference: {log_ev_analytic - log_ev_pkg:.2e}")
# Out:
# Analytical log evidence (mpmath): -91.738538
# Package log evidence: -91.738538
# Difference: -2.84e-14

# %% [markdown]
# ## 2. Posterior density
#
# The posterior density is given by (16). We compute it over a range of λ values and plot.

# %%
lambda_vals = np.linspace(1e-6, 1, 500)
log_post = deriv.post_density(lambda_vals, log=True)
post = np.exp(log_post)

plt.figure(figsize=(8,5))
plt.plot(lambda_vals, post)
plt.xlabel(r'$\lambda$')
plt.ylabel('Posterior density')
plt.title('Posterior density of the common failure rate')
plt.grid()
plt.show()

# %% [markdown]
# ## 3. Posterior predictive mass
#
# We compute the predictive mass for a new observation at pump 4's exposure (`t_new = 125.76`) and compare with the observed `y=14`.

# %%
t_new = 125.76
y_new = 14
log_pred = deriv.post_predictive(pd.DataFrame({'y': [y_new]}), scale=t_new, log=True)
print(f"Log predictive mass at y_new={y_new}: {log_pred:.6f}")
print(f"Predictive mass: {np.exp(log_pred):.6e}")
# Out:
# Log predictive mass at y_new=14: -5.250132
# Predictive mass: 5.246825e-03

# %% [markdown]
# ## 4. Posterior MGF
#
# The posterior MGF as a function of `r` (for `r < 0`):

# %%
r_vals = np.linspace(-2e5, 200, 100)
cgf_vals = [deriv.post_mgf(r, log=True) for r in r_vals]

plt.figure(figsize=(8,5))
plt.plot(r_vals, cgf_vals)
plt.xlabel('r')
plt.ylabel('Posterior CGF')
plt.title('Posterior CGF of the rate parameter')
plt.grid()
plt.show()

# %% [markdown]
# ## 5. Posterior moments
#
# We compute the first few moments (mean, variance, etc.) using the `post_moment` method.

# %%
for q in [1, 2, 3, 4]:
    moment = deriv.post_moment(q, log=False)
    print(f"E[λ^{q}] = {moment:.6e}")
# Out:
# E[λ^1] = 2.142661e-01
# E[λ^2] = 4.652209e-02
# E[λ^3] = 1.023392e-02
# E[λ^4] = 2.280494e-03

# %% [markdown]
# ## 6. Sequential updating
#
# We split the data into two chunks: first 5 pumps, then the remaining 5. We update sequentially and compare the final evidence with the full-dataset evidence.

# %%
# Split data
data1 = data.iloc[:5]
data2 = data.iloc[5:]

# First chunk
deriv1 = MGFDerivative(
    prior='pareto',
    data=data1['y'],
    likelihood='poisson',
    method='symbolic',
    params=params_pareto,
    scale=data1['t']
)

# Update with second chunk (using jax for speed)
deriv2 = deriv1.update(
    new_data=data2['y'],
    method='jax',
    scale=data2['t']
)

# Sequential log evidence: log evidence of chunk1 + log predictive of chunk2
log_ev_seq = deriv1.evidence()[0] + deriv2.evidence()[0]
print(f"Sequential log evidence: {log_ev_seq:.6f}")
print(f"Full data log evidence: {log_ev:.6f}")
print(f"Difference: {log_ev_seq - log_ev:.2e}")
# Out:
# ---------------------------------------------------------------------------
# ConcretizationTypeError                   Traceback (most recent call last)
# Cell In[16], line 16
#      12     scale=data1['t']
#      13 )
#      14
#      15 # Update with second chunk (using jax for speed)
# ---> 16 deriv2 = deriv1.update(
#      17     new_data=data2['y'],
#      18     method='jax',
#      19     scale=data2['t']
#
# File ~/Documents/GitHub/mgf2post/mgf2post/MGFderivative_class.py:1090, in MGFDerivative.update(self, new_data, method, log, simplify, params, **kwargs)
#    1087 merged_ready = {**self._ready_kwargs, **kwargs}
#    1089 # For numeric route, params is ignored (custom prior is numeric)
# -> 1090 return MGFDerivative(
#    1091     prior='custom',
#    1092     data=new_data,
#    1093     likelihood=self.likelihood,
#    1094     method=method,
#    1095     params=None,                     # numeric custom prior has embedded parameters
#    1096     simplify=simplify,
#    1097     log=log,
#    1098     prior_mgf_func=post_mgf,
#    1099     prior_cgf_func=post_cgf,
#    1100     prior_pdf_func=post_pdf,
#    1101     prior_logpdf_func=post_logpdf,
#    1102     prior_pdf_sym_func=None,
#    1103     **merged_ready
#    1104 )
#
# File ~/Documents/GitHub/mgf2post/mgf2post/MGFderivative_class.py:320, in MGFDerivative.__init__(self, prior, data, likelihood, method, params, simplify, log, prior_mgf_func, prior_cgf_func, prior_pdf_func, prior_logpdf_func, prior_pdf_sym_func, prior_mgf_sym, prior_cgf_sym, **kwargs)
#     318     self._compute_derivative_special()
#     319 else:
# --> 320     self._compute_derivative_standard()
#
# File ~/Documents/GitHub/mgf2post/mgf2post/MGFderivative_class.py:382, in MGFDerivative._compute_derivative_standard(self)
#     380 for _ in range(int(round(self.a))):
#     381     f = jax.grad(f, argnums=0)
# --> 382 deriv_val = float(f(t_jax))
#     383 # Store numeric result
#     384 if abs(deriv_val) < 1e-300:
#
#     [... skipping hidden 10 frame]
#
#     [... skipping similar frames: api_boundary.<locals>.reraise_with_filtered_traceback at line 196 (1 times)]
#
#     [... skipping hidden 1 frame]
#
#     [... skipping similar frames: api_boundary.<locals>.reraise_with_filtered_traceback at line 196 (1 times)]
#
#     [... skipping hidden 7 frame]
#
#     [... skipping similar frames: api_boundary.<locals>.reraise_with_filtered_traceback at line 196 (89 times), _argnums_partial at line 264 (44 times), _vjp at line 2212 (44 times), WrappedFun.call_wrapped at line 212 (44 times), direct_linearize at line 306 (44 times), flatten_fun_nokwargs at line 91 (44 times), grad.<locals>.grad_f at line 469 (44 times), linearize at line 331 (44 times), value_and_grad.<locals>.value_and_grad_f at line 545 (44 times)]
#
#     [... skipping hidden 9 frame]
#
# File ~/Documents/GitHub/mgf2post/mgf2post/MGFderivative_class.py:1081, in MGFDerivative.update.<locals>.<lambda>(r_val, *args)
#    1065     return MGFDerivative(
#    1066         prior='custom',
#    1067         data=new_data,
#    (...)   1076         **merged_ready
#    1077     )
#    1079 # ---- Numeric sequential update ----
#    1080 # Create numeric lambdas using existing methods
# -> 1081 post_mgf = lambda r_val, *args: self.post_mgf(r_val, log=False)
#    1082 post_cgf = lambda r_val, *args: self.post_mgf(r_val, log=True)
#    1083 post_pdf = lambda theta, *args: self.post_density(theta, log=False)
#
# File ~/Documents/GitHub/mgf2post/mgf2post/MGFderivative_class.py:880, in MGFDerivative.post_mgf(self, r, log)
#     873 if r is None:
#     874     raise ValueError("For numeric evaluation, r must be provided.")
#     876 log_abs_num, sign_num = mgfDerivative(
#     877     order=self.a,
#     878     prior=self.prior,
#     879     method=self.method,
# --> 880     t=float(r - self.b),
#     881     params=self.params,
#     882     simplify=self.simplify,
#     883     log=True,
#     884     **self._deriv_kwargs
#     885 )
#     887 log_ratio = log_abs_num - self.log_abs
#     888 sign_ratio = sign_num * self.sign
#
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/envs/mgf2post_conda/lib/python3.12/site-packages/jax/_src/core.py:1879, in concretization_function_error.<locals>.error(self, arg)
#    1878 def error(self, arg):
# -> 1879   raise ConcretizationTypeError(arg, fname_context)
#
# ConcretizationTypeError: Abstract tracer value encountered where concrete value is expected: traced array with shape float64[]
# The problem arose with the `float` function. If trying to convert the data type of a value, try using `x.astype(float)` or `jnp.array(x, float)` instead.
#
# See https://docs.jax.dev/en/latest/errors.html#jax.errors.ConcretizationTypeError
